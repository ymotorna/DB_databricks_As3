# %%
# setup working environment
catalog_name = "ymotorna_DB"
schema_name  = "superstore_lakehouse"
volume_name  = "raw_data"

# +hierarchy (catalog -> schema -> volume)
spark.sql(f"CREATE CATALOG IF NOT EXISTS {catalog_name}")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {catalog_name}.{schema_name}")
spark.sql(f"CREATE VOLUME IF NOT EXISTS {catalog_name}.{schema_name}.{volume_name}")
# Out:
# DataFrame[]

# %%
# %sql

--  check environment + file existance
LIST '/Volumes/ymotorna_DB/superstore_lakehouse/raw_data/';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modification_time</th></tr></thead><tbody><tr><td>/Volumes/ymotorna_DB/superstore_lakehouse/raw_data/superstore_data.csv</td><td>superstore_data.csv</td><td>2287806</td><td>1782728257000</td></tr></tbody></table></div>
